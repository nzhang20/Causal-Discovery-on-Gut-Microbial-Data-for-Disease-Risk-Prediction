# %%
import pandas as pd
import numpy as np
import biom

# %%
samples = []
forward_fastq = []

for i in range(31, 45):
    samples.append(f'sample-{i}')
    forward_fastq.append(f'/Users/candusshi/academics/qiime2-capstone/pipeline/SRR129298{i}_1.fastq.gz')

# %%
manifest = pd.DataFrame({'sample-id': samples, 'absolute-filepath': forward_fastq})
manifest.to_csv('/Users/candusshi/academics/qiime2-capstone/pipeline/manifest.tsv', sep='\t', index=False)

# %%
hoangle = biom.load_table('/Users/candusshi/academics/qiime2-capstone/pipeline/exported-feature-table-matched/feature-table.biom')
hoangle.to_dataframe()
# Out:
#                                                     sample-33  sample-34  \
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...     2364.0      362.0
# d__Bacteria;p__Bacillota_A_368345;c__Clostridia...      348.0     2197.0
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...      463.0    10108.0
# d__Bacteria;p__Bacillota_A_368345;c__Clostridia...      194.0      282.0
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...       50.0       78.0
# ...                                                       ...        ...
# d__Bacteria;p__Bacillota_C;c__Negativicutes;o__...          0          0
# d__Bacteria;p__Bacillota_I;c__Bacilli_A;o__Lact...          0          0
# d__Bacteria;p__Pseudomonadota;c__Gammaproteobac...          0          0
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...          0          0
# d__Bacteria;p__Bacillota_A_368345;c__Clostridia...          0          0
#
#                                                     sample-31  sample-32  \
# ...
